# %%
## Diabetes 
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

data = pd.read_csv("D:/smart decision/Data Preprocessing/Cleaned Datasets/cleaned_diabetic_data.csv")

X = data.drop("readmitted", axis=1)
y = data["readmitted"]

le = LabelEncoder()

for col in X.select_dtypes(include="object").columns:
    X[col] = le.fit_transform(X[col].astype(str))

y = le.fit_transform(y)


selector = SelectKBest(score_func=chi2, k=5)

X = selector.fit_transform(X, y)


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42
)

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

final_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42
)

final_model.fit(X_train, y_train)

y_pred = final_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5847810706705447

# %%
## Saved the model
import joblib

joblib.dump(
    final_model,
    r"D:\smart decision\Final models\diabetic_readmission_model.pkl"
)

loaded_model = joblib.load(
    r"D:\smart decision\Final models\diabetic_readmission_model.pkl"
)

print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
# =====================================================
# PNEUMONIA FINAL MODEL - COMPLETE CORRECTED VERSION
# =====================================================

import os
import pandas as pd
import joblib

from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)


# =====================================================
# 1. LOAD DATASET
# =====================================================

data = pd.read_csv(
    r"D:\smart decision\Data Preprocessing\Cleaned Datasets\cleaned_clinical_pneumonia_dataset.csv"
)

print("Dataset Shape:", data.shape)

print("\nColumns:")
print(data.columns.tolist())


# =====================================================
# 2. CREATE X AND y
# REMOVE TARGET AND TIMESTAMP
# =====================================================

X = data.drop(
    ["true_label", "timestamp"],
    axis=1
).copy()

y = data["true_label"].copy()


# Save original feature names

original_feature_names = X.columns.tolist()


# =====================================================
# 3. ENCODE CATEGORICAL FEATURES
# =====================================================

feature_encoders = {}

categorical_columns = X.select_dtypes(
    include=["object", "category"]
).columns


for col in categorical_columns:

    encoder = LabelEncoder()

    X[col] = encoder.fit_transform(
        X[col].astype(str)
    )

    feature_encoders[col] = encoder


print("\nEncoded Categorical Columns:")

print(
    list(feature_encoders.keys())
)


# =====================================================
# 4. ENCODE TARGET
# =====================================================

target_encoder = LabelEncoder()

y = target_encoder.fit_transform(
    y.astype(str)
)


print("\nTarget Class Mapping:")

for number, class_name in enumerate(
    target_encoder.classes_
):

    print(
        number,
        "=",
        class_name
    )


# =====================================================
# 5. FEATURE SELECTION
# =====================================================

selector = SelectKBest(
    score_func=chi2,
    k=5
)


X_selected = selector.fit_transform(
    X,
    y
)


# Get exact selected feature names

selected_feature_names = X.columns[
    selector.get_support()
].tolist()


print("\n======================================")
print("SELECTED FEATURES FOR DASHBOARD")
print("======================================")


for feature in selected_feature_names:

    print(feature)


# =====================================================
# 6. TRAIN TEST SPLIT
# =====================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)


# =====================================================
# 7. STANDARD SCALING
# =====================================================

scaler = StandardScaler()


X_train_scaled = scaler.fit_transform(
    X_train
)


X_test_scaled = scaler.transform(
    X_test
)


# =====================================================
# 8. FINAL RANDOM FOREST MODEL
# =====================================================

final_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42
)


final_model.fit(
    X_train_scaled,
    y_train
)


# =====================================================
# 9. MODEL PREDICTION
# =====================================================

y_pred = final_model.predict(
    X_test_scaled
)


# =====================================================
# 10. MODEL PERFORMANCE
# =====================================================

print("\n======================================")
print("MODEL PERFORMANCE")
print("======================================")


print(
    "\nAccuracy:",
    accuracy_score(
        y_test,
        y_pred
    )
)


print(
    "\nConfusion Matrix:"
)


print(
    confusion_matrix(
        y_test,
        y_pred
    )
)


print(
    "\nClassification Report:"
)


print(
    classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_
    )
)


# =====================================================
# 11. SAVE FOLDER
# =====================================================

SAVE_FOLDER = (
    r"D:\smart decision\Final models\Pneumoia"
)


os.makedirs(
    SAVE_FOLDER,
    exist_ok=True
)


# =====================================================
# 12. SAVE MODEL
# =====================================================

joblib.dump(
    final_model,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_model.pkl"
    )
)


# =====================================================
# 13. SAVE SELECTOR
# =====================================================

joblib.dump(
    selector,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_selector.pkl"
    )
)


# =====================================================
# 14. SAVE SCALER
# =====================================================

joblib.dump(
    scaler,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_scaler.pkl"
    )
)


# =====================================================
# 15. SAVE TARGET ENCODER
# =====================================================

joblib.dump(
    target_encoder,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_target_encoder.pkl"
    )
)


# =====================================================
# 16. SAVE FEATURE ENCODERS
# =====================================================

joblib.dump(
    feature_encoders,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_feature_encoders.pkl"
    )
)


# =====================================================
# 17. SAVE ORIGINAL FEATURE NAMES
# =====================================================

joblib.dump(
    original_feature_names,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_original_features.pkl"
    )
)


# =====================================================
# 18. SAVE SELECTED FEATURE NAMES
# =====================================================

joblib.dump(
    selected_feature_names,
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_selected_features.pkl"
    )
)


# =====================================================
# 19. TEST SAVED MODEL
# =====================================================

loaded_model = joblib.load(
    os.path.join(
        SAVE_FOLDER,
        "Pneumonia_model.pkl"
    )
)


test_prediction = loaded_model.predict(
    X_test_scaled[:1]
)


actual_result = (
    target_encoder.inverse_transform(
        test_prediction
    )[0]
)


print("\n======================================")
print("ALL FILES SAVED SUCCESSFULLY!")
print("======================================")


print("\nSaved Model Test Prediction:")

print(actual_result)


print("\nSelected Dashboard Features:")

print(selected_feature_names)


print("\nTarget Classes:")

print(target_encoder.classes_)


# =====================================================
# 20. FIND EXACT WORKING DASHBOARD TEST CASES
# =====================================================

print("\n\n======================================")
print("FINDING EXACT DASHBOARD TEST CASES")
print("======================================")


# Scale the complete selected dataset
# using the same scaler used by the dashboard

all_scaled = scaler.transform(
    X_selected
)


# Predict every dataset row

all_predictions = final_model.predict(
    all_scaled
)


# Convert predictions back to class names

all_prediction_names = (
    target_encoder.inverse_transform(
        all_predictions
    )
)


print("\n======================================")
print("EXACT WORKING DASHBOARD TEST CASES")
print("======================================")


# Find one exact model-predicted row
# for every target condition

for class_name in target_encoder.classes_:

    matching_positions = [

        i

        for i, predicted_class
        in enumerate(all_prediction_names)

        if predicted_class == class_name
    ]


    if matching_positions:

        i = matching_positions[0]


        print("\n--------------------------------------")

        print(
            "EXPECTED RESULT:",
            class_name.upper()
        )

        print("--------------------------------------")


        for feature in selected_feature_names:

            value = X.iloc[i][feature]


            # Convert encoded categorical value
            # back to original dashboard wording

            if feature in feature_encoders:

                value = feature_encoders[
                    feature
                ].inverse_transform(
                    [int(value)]
                )[0]


            print(
                feature,
                "=",
                value
            )


    else:

        print("\n--------------------------------------")

        print(
            "NO TEST CASE FOUND FOR:",
            class_name.upper()
        )

        print("--------------------------------------")


print("\n======================================")
print("TEST CASE SEARCH COMPLETED")
print("======================================")
# Out:
# Dataset Shape: (1500, 9)
#
# Columns:
# ['timestamp', 'fever', 'tachycardia', 'crackles', 'oxygen_saturation', 'wbc_count', 'chest_xray_result', 'true_label', 'uncertainty_score']
#
# Encoded Categorical Columns:
# ['chest_xray_result']
#
# Target Class Mapping:
# 0 = atelectasis
# 1 = pneumonia
# 2 = pulmonary edema
#
# ...
# SELECTED FEATURES FOR DASHBOARD
# ...
# tachycardia
# crackles
# wbc_count
# chest_xray_result
# uncertainty_score
#
# ...
# MODEL PERFORMANCE
# ...
#
# Accuracy: 0.6
#
# Confusion Matrix:
# [[ 70  16  39]
#  [ 13 106   6]
#  [ 55  21  49]]
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#     atelectasis       0.51      0.56      0.53       125
#       pneumonia       0.74      0.85      0.79       125
# pulmonary edema       0.52      0.39      0.45       125
#
#        accuracy                           0.60       375
#       macro avg       0.59      0.60      0.59       375
#    weighted avg       0.59      0.60      0.59       375
#
#
# ...

# %%
## Length of Stay Final Model

import pandas as pd
import joblib
import numpy as np

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

data = pd.read_csv(r"D:\smart decision\Data Preprocessing\Cleaned Datasets\cleaned_LengthOfStay.csv")

X = data.drop("lengthofstay", axis=1)
y = data["lengthofstay"]

le = LabelEncoder()

for col in X.select_dtypes(include="object").columns:
    X[col] = le.fit_transform(X[col].astype(str))


X_train, X_test, y_train, y_test = train_test_split( X, y,test_size=0.25,random_state=42)


sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


final_model = RandomForestRegressor(
    n_estimators=100,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42
)

final_model.fit(X_train, y_train)


y_pred = final_model.predict(X_test)

print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE :", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score :", r2_score(y_test, y_pred))


joblib.dump(
    final_model,
    r"D:\smart decision\Final models\Length of stay\lengthofstay_model.pkl"
)

loaded_model = joblib.load(
    r"D:\smart decision\Final models\Length of stay\lengthofstay_model.pkl"
)

print("Length of Stay Model Saved Successfully!")

print("Saved Successfully!")
# Out:
# MAE : 0.6381967606631963
# MSE : 0.7211511070720268
# RMSE : 0.8492061628792074
# R2 Score : 0.8687058823453968
# Length of Stay Model Saved Successfully!
# Saved Successfully!

# %%
# =====================================================
# HOSPITAL ANALYSIS FINAL MODEL - CORRECTED VERSION
# =====================================================

import os
import pandas as pd
import joblib

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)


# =====================================================
# 1. LOAD DATASET
# =====================================================

data = pd.read_csv(
    r"D:\smart decision\Data Preprocessing\Cleaned Datasets\cleaned_hospital_data_analysis.csv"
)

print("Dataset Shape:", data.shape)

print("\nColumns:")
print(data.columns.tolist())


# =====================================================
# 2. CREATE X AND y
# =====================================================

X = data.drop(
    "Outcome",
    axis=1
).copy()

y = data["Outcome"].copy()


original_feature_names = X.columns.tolist()


# =====================================================
# 3. ENCODE EACH CATEGORICAL FEATURE SEPARATELY
# =====================================================

feature_encoders = {}

categorical_columns = X.select_dtypes(
    include=["object", "category"]
).columns


for col in categorical_columns:

    encoder = LabelEncoder()

    X[col] = encoder.fit_transform(
        X[col].astype(str)
    )

    feature_encoders[col] = encoder


print("\nEncoded Categorical Columns:")

print(
    list(feature_encoders.keys())
)


# =====================================================
# 4. ENCODE TARGET SEPARATELY
# =====================================================

target_encoder = LabelEncoder()

y = target_encoder.fit_transform(
    y.astype(str)
)


print("\nTarget Class Mapping:")

for number, class_name in enumerate(
    target_encoder.classes_
):

    print(
        number,
        "=",
        class_name
    )


# =====================================================
# 5. FEATURE SELECTION
# =====================================================

selector = SelectKBest(
    score_func=chi2,
    k=5
)


X_selected = selector.fit_transform(
    X,
    y
)


selected_feature_names = X.columns[
    selector.get_support()
].tolist()


print("\n======================================")
print("SELECTED FEATURES FOR DASHBOARD")
print("======================================")


for feature in selected_feature_names:

    print(feature)


# =====================================================
# 6. TRAIN TEST SPLIT
# =====================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)


# =====================================================
# 7. STANDARD SCALER
# =====================================================

scaler = StandardScaler()


X_train_scaled = scaler.fit_transform(
    X_train
)


X_test_scaled = scaler.transform(
    X_test
)


# =====================================================
# 8. RANDOM FOREST MODEL
# =====================================================

final_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42
)


final_model.fit(
    X_train_scaled,
    y_train
)


y_pred = final_model.predict(
    X_test_scaled
)



print(
    "\nAccuracy:",
    accuracy_score(
        y_test,
        y_pred
    )
)


print("\nConfusion Matrix:")

print(
    confusion_matrix(
        y_test,
        y_pred
    )
)


print("\nClassification Report:")

print(
    classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_
    )
)



SAVE_FOLDER = (
    r"D:\smart decision\Final models\Hospital Analysis"
)


os.makedirs(
    SAVE_FOLDER,
    exist_ok=True
)


joblib.dump(
    final_model,
    os.path.join(
        SAVE_FOLDER,
        "hospital_model.pkl"
    )
)


joblib.dump(
    selector,
    os.path.join(
        SAVE_FOLDER,
        "hospital_selector.pkl"
    )
)


joblib.dump(
    scaler,
    os.path.join(
        SAVE_FOLDER,
        "hospital_scaler.pkl"
    )
)


joblib.dump(
    feature_encoders,
    os.path.join(
        SAVE_FOLDER,
        "hospital_feature_encoders.pkl"
    )
)


joblib.dump(
    target_encoder,
    os.path.join(
        SAVE_FOLDER,
        "hospital_target_encoder.pkl"
    )
)


joblib.dump(
    original_feature_names,
    os.path.join(
        SAVE_FOLDER,
        "hospital_original_features.pkl"
    )
)


joblib.dump(
    selected_feature_names,
    os.path.join(
        SAVE_FOLDER,
        "hospital_selected_features.pkl"
    )
)


print("\nSelected Dashboard Features:")

print(selected_feature_names)


print("\nTarget Classes:")

print(target_encoder.classes_)


all_scaled = scaler.transform(
    X_selected
)


all_predictions = final_model.predict(
    all_scaled
)


all_prediction_names = (
    target_encoder.inverse_transform(
        all_predictions
    )
)


for class_name in target_encoder.classes_:

    matching_positions = [

        i

        for i, predicted_class
        in enumerate(all_prediction_names)

        if predicted_class == class_name
    ]


    if matching_positions:

        i = matching_positions[0]

        print(
            "EXPECTED RESULT:",
            class_name.upper()
        )


        for feature in selected_feature_names:

            value = X.iloc[i][feature]


            if feature in feature_encoders:

                value = feature_encoders[
                    feature
                ].inverse_transform(
                    [int(value)]
                )[0]


            print(
                feature,
                "=",
                value
            )


    else:

        print(
            "\nNO TEST CASE FOUND FOR:",
            class_name.upper()
        )
# Out:
# Dataset Shape: (984, 9)
#
# Columns:
# ['Age', 'Gender', 'Condition', 'Procedure', 'Cost', 'Length_of_Stay', 'Readmission', 'Outcome', 'Satisfaction']
#
# Encoded Categorical Columns:
# ['Gender', 'Condition', 'Procedure', 'Readmission']
#
# Target Class Mapping:
# 0 = Recovered
# 1 = Stable
#
# ...
# SELECTED FEATURES FOR DASHBOARD
# ...
# Age
# Condition
# Procedure
# Cost
# Satisfaction
#
# Accuracy: 1.0
#
# Confusion Matrix:
# [[148   0]
#  [  0  98]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Recovered       1.00      1.00      1.00       148
#       Stable       1.00      1.00      1.00        98
#
#     accuracy                           1.00       246
#    macro avg       1.00      1.00      1.00       246
# weighted avg       1.00      1.00      1.00       246
#
#
# Selected Dashboard Features:
# ['Age', 'Condition', 'Procedure', 'Cost', 'Satisfaction']
#
# Target Classes:
# ['Recovered' 'Stable']
# EXPECTED RESULT: RECOVERED
# Age = 45
# ...
